# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'/Users/nicholasdougherty/codeup-data-science/Tableau /Sheets/CustDetails.csv')

# %%
# csv2 = pd.read_csv(r'/Users/nicholasdougherty/Downloads/Tableau Spreadsheets Cleaned for Seaborn - Sheet12.csv')
# this is a cleaned datasheet that only includes Month-to-Month.

# %% [markdown]
# /Users/nicholasdougherty/codeup-data-science/Tableau/Sheets/CustDetails.csv

# %%
def describe_data(df):
    print(df.isna().sum())
    print(df.info())
    print(df.describe())
    return print('End')

describe_data(df)
# Out:
# customer_id                0
# gender                     0
# is_senior_citizen          0
# partner                    0
# dependents                 0
# phone_service              0
# phone_service_name         0
# internet_service           0
# internet_service_name      0
# contract_type              0
# contract_name              0
# payment_type               0
# monthly_charges            0
# total_charges             11
# tenure                     0
# total_charges2             0
# total_charges_match        0
# churn                      0
# is_female                  0
# has_churned                0
# has_phone                  0
# has_internet               0
# has_phone_and_internet     0
# partner_dependents         0
# partner_dependents.1       0
# service_type               0
# tenure_months              0
# tenure_years               0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 28 columns):
# ...

# %%
df.corr()
# Out:
#                         is_senior_citizen  phone_service  internet_service  \
# is_senior_citizen                1.000000       0.114023          0.259382
# phone_service                    0.114023       1.000000          0.307939
# internet_service                 0.259382       0.307939          1.000000
# contract_type                   -0.142695       0.083212         -0.290514
# monthly_charges                  0.220207       0.490643          0.905564
# total_charges                    0.102420       0.412479          0.428483
# tenure                           0.016062       0.258880          0.032530
# is_female                        0.001869       0.009216          0.010547
# has_churned                      0.150912       0.036013          0.316695
# has_phone                        0.008658       0.675108          0.093590
# has_internet                     0.182833       0.082639          0.825978
# ...

# %%
df.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  1371-DWPAZ  Female                  0     Yes        Yes              0
# 1  2520-SGTTA  Female                  0     Yes        Yes              1
# 2  2775-SEFEE    Male                  0      No        Yes              2
# 3  2923-ARZLG    Male                  0     Yes        Yes              1
# 4  3115-CZMZD    Male                  0      No        Yes              1
#
#   phone_service_name  internet_service internet_service_name  contract_type  \
# 0   No Phone Service                 1                   DSL              2
# 1           One Line                 0   No Internet Service              2
# 2  Two or More Lines                 1                   DSL              2
# 3           One Line                 0   No Internet Service              1
# 4           One Line                 0   No Internet Service              2
#
# ...

# %%
sns.set(style='darkgrid')
# Your code goes here
fig, ax = plt.subplots(3, 3, figsize=(14, 12))
sns.countplot(data=df, x='gender', hue='has_churned', ax=ax[0][0])
sns.countplot(data=df, x='partner', hue='has_churned', ax=ax[0][1])
sns.countplot(data=df, x='is_senior_citizen', hue='has_churned', ax=ax[0][2])
sns.countplot(data=df, x='service_type', hue='has_churned', ax=ax[1][0])
sns.countplot(data=df, x='internet_service_name', hue='has_churned', ax=ax[1][1])
sns.countplot(data=df, x='payment_type', hue='has_churned', ax=ax[1][2])
sns.countplot(data=df, x='partner_dependents', hue='has_churned', ax=ax[2][0])
sns.countplot(data=df, x='has_phone_and_internet', hue='has_churned', ax=ax[2][1])

plt.tight_layout()
plt.show()

# %%
sns.set(style='whitegrid')
sns.set(rc = {'figure.figsize':(15,8)})
sns.countplot(data=df, x='payment_type', hue='has_churned')
plt.show()

# %%
df.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  1371-DWPAZ  Female                  0     Yes        Yes              0
# 1  2520-SGTTA  Female                  0     Yes        Yes              1
# 2  2775-SEFEE    Male                  0      No        Yes              2
# 3  2923-ARZLG    Male                  0     Yes        Yes              1
# 4  3115-CZMZD    Male                  0      No        Yes              1
#
#   phone_service_name  internet_service internet_service_name  contract_type  \
# 0   No Phone Service                 1                   DSL              2
# 1           One Line                 0   No Internet Service              2
# 2  Two or More Lines                 1                   DSL              2
# 3           One Line                 0   No Internet Service              1
# 4           One Line                 0   No Internet Service              2
#
# ...

# %%
# To inspire functions in Tableau 
welcome_to_the_internet = df[['internet_service_name', 'has_churned']].groupby('internet_service_name').mean()
print(welcome_to_the_internet)

# Fiber Optics, we need to talk. How much more do you cost than DSL?

doormat = df[['internet_service_name', 'monthly_charges']].groupby('internet_service_name').mean()
print(doormat)

#Quite a bit more expensive. But this doesn't only factor in those who are on a month-to-month plan. I'll do that
#in Tableau.
# Out:
#                        has_churned
# internet_service_name
# DSL                       0.189926
# Fiber Optic               0.418657
# No Internet Service       0.073905
#                        monthly_charges
# internet_service_name
# DSL                          58.090772
# Fiber Optic                  91.503970
# No Internet Service          21.076880

# %%
# I'm most interest in payment_type. 

electronica = df[['payment_type', 'has_churned']].groupby('payment_type').mean()
print(electronica)
# Out:
#                            has_churned
# payment_type
# Bank transfer (automatic)     0.167313
# Credit card (automatic)       0.152231
# Electronic check              0.452854
# Mailed check                  0.191067

# %%
# the impact of electronic check has a greater mean than fiber optic does. That alone draws me to it more. But why
# just look at mean? I will observe the overall count in Tableau. 
#check distribution plots in Tableau, as possible, for Tenure and Monthly charges.

# %%
df[['tenure_months', 'monthly_charges', 'has_churned']].groupby('has_churned').mean()
# Out:
#              tenure_months  monthly_charges
# has_churned
# False            37.577525        61.255136
# True             17.965775        74.417834

# %% [markdown]
# The first two-or-so years are critical. If TelcoCo successfully holds on for the first two years, long term probability of preventing churn steers more favorably. The monthly charges play a role, too; perhaps customers would benefit from a reduced rate for the first-year, which then afterwards switches to the standard rate, whatever that may be.
#
# I could calculate the average monthly charges by tenants whose tenure exceeds 3 years, and suggest a reduction of that amount for new-customers. After enough time lapses, then that amount will be matched.

# %% [markdown]
# Going forward, I will look into attribute relevance analysis and attempt to use it in the future for assignments like these.
